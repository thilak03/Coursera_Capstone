# %% [markdown]
# ## Install beautifulsoup4 to scrap webpage

# %%
pip install beautifulsoup4

# %% [markdown]
# ## Import requests package to get the html content of a webpage
# ## Then get the html content of the canada postal codes webpage into a variable

# %%
import requests
html_content = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text

# %% [markdown]
# ### Parse the content using beautiful soup html parser and print it

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')
#print(soup.prettify()) # print the parsed data of html

# %% [markdown]
# ## Print the title of the webpage

# %%
print(soup.title)
# Out:
# <title>List of postal codes of Canada: M - Wikipedia</title>

# %% [markdown]
# ### By doing webpage inspect get the class name of the table and assign that table to a variable
# ### Get the header of the table using tag "th" and print the headers after removing spaces and new line character

# %%
canada_table = soup.find("table", attrs={"class": "wikitable sortable"})

t_headers = []
for th in canada_table.find_all("th"):
 # remove any newlines and extra spaces from left and right
 t_headers.append(th.text.replace('\n', ' ').strip())        
   
    
print(t_headers)
# Out:
# ['Postal Code', 'Borough', 'Neighborhood']

# %% [markdown]
# ## Get all rows from the table's body and assign that to an array

# %%
    table_data = []
    for tr in canada_table.tbody.find_all("tr"): # find all tr's from table's tbody
        t_row = {}
        # Each table row is stored in the form of
        # t_row = {'Postal Code': '', 'Borough': '', 'Neighborhood': ''}

        # find all td's(3) in tr and zip it with t_header
        for td, th in zip(tr.find_all("td"), t_headers): 
            t_row[th] = td.text.replace('\n', '').strip()
        table_data.append(t_row)

#Remove first record
table_data.pop(0) 
print(table_data[0])
# Out:
# {'Postal Code': 'M1A', 'Borough': 'Not assigned', 'Neighborhood': 'Not assigned'}

# %% [markdown]
# ## Import pandas to create data frame

# %%
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Define the data frame columns and instantiate the data frame

# %%
# define the dataframe columns
column_names = ['PostalCode', 'Borough', 'Neighborhood'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)
neighborhoods
# Out:
# Empty DataFrame
# Columns: [PostalCode, Borough, Neighborhood]
# Index: []

# %% [markdown]
# ## Get the values form array and assign it to the corresponding columns in the data frame

# %%
for data in table_data:
    Borough = data['Borough']
    PostalCode = data['Postal Code']
    Neighborhood = data['Neighborhood']
    
    
    neighborhoods = neighborhoods.append({'Borough': Borough,
                                          'PostalCode': PostalCode,
                                          'Neighborhood': Neighborhood}, ignore_index=True)

# %%
neighborhoods
# Out:
#     PostalCode           Borough  \
# 0          M1A      Not assigned
# 1          M2A      Not assigned
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# 5          M6A        North York
# 6          M7A  Downtown Toronto
# 7          M8A      Not assigned
# 8          M9A         Etobicoke
# 9          M1B       Scarborough
# 10         M2B      Not assigned
# 11         M3B        North York
# 12         M4B         East York
# 13         M5B  Downtown Toronto
# 14         M6B        North York
# 15         M7B      Not assigned
# 16         M8B      Not assigned
# 17         M9B         Etobicoke
# 18         M1C       Scarborough
# 19         M2C      Not assigned
# 20         M3C        North York
# 21         M4C         East York
# 22         M5C  Downtown Toronto
# 23         M6C              York
# 24         M7C      Not assigned
# 25         M8C      Not assigned
# 26         M9C         Etobicoke
# 27         M1E       Scarborough
# 28         M2E      Not assigned
# 29         M3E      Not assigned
# 30         M4E      East Toronto
# 31         M5E  Downtown Toronto
# 32         M6E              York
# 33         M7E      Not assigned
# 34         M8E      Not assigned
# 35         M9E      Not assigned
# 36         M1G       Scarborough
# 37         M2G      Not assigned
# 38         M3G      Not assigned
# 39         M4G         East York
# 40         M5G  Downtown Toronto
# 41         M6G  Downtown Toronto
# 42         M7G      Not assigned
# 43         M8G      Not assigned
# 44         M9G      Not assigned
# 45         M1H       Scarborough
# 46         M2H        North York
# 47         M3H        North York
# 48         M4H         East York
# 49         M5H  Downtown Toronto
# 50         M6H      West Toronto
# 51         M7H      Not assigned
# 52         M8H      Not assigned
# 53         M9H      Not assigned
# 54         M1J       Scarborough
# 55         M2J        North York
# 56         M3J        North York
# 57         M4J         East York
# 58         M5J  Downtown Toronto
# 59         M6J      West Toronto
# 60         M7J      Not assigned
# 61         M8J      Not assigned
# 62         M9J      Not assigned
# 63         M1K       Scarborough
# 64         M2K        North York
# 65         M3K        North York
# 66         M4K      East Toronto
# 67         M5K  Downtown Toronto
# 68         M6K      West Toronto
# 69         M7K      Not assigned
# 70         M8K      Not assigned
# 71         M9K      Not assigned
# 72         M1L       Scarborough
# 73         M2L        North York
# 74         M3L        North York
# 75         M4L      East Toronto
# 76         M5L  Downtown Toronto
# 77         M6L        North York
# 78         M7L      Not assigned
# 79         M8L      Not assigned
# 80         M9L        North York
# 81         M1M       Scarborough
# 82         M2M        North York
# 83         M3M        North York
# 84         M4M      East Toronto
# 85         M5M        North York
# 86         M6M              York
# 87         M7M      Not assigned
# 88         M8M      Not assigned
# 89         M9M        North York
# 90         M1N       Scarborough
# 91         M2N        North York
# 92         M3N        North York
# 93         M4N   Central Toronto
# 94         M5N   Central Toronto
# 95         M6N              York
# 96         M7N      Not assigned
# 97         M8N      Not assigned
# 98         M9N              York
# 99         M1P       Scarborough
# 100        M2P        North York
# 101        M3P      Not assigned
# 102        M4P   Central Toronto
# 103        M5P   Central Toronto
# 104        M6P      West Toronto
# 105        M7P      Not assigned
# 106        M8P      Not assigned
# 107        M9P         Etobicoke
# 108        M1R       Scarborough
# 109        M2R        North York
# 110        M3R      Not assigned
# 111        M4R   Central Toronto
# 112        M5R   Central Toronto
# 113        M6R      West Toronto
# 114        M7R       Mississauga
# 115        M8R      Not assigned
# 116        M9R         Etobicoke
# 117        M1S       Scarborough
# 118        M2S      Not assigned
# 119        M3S      Not assigned
# 120        M4S   Central Toronto
# 121        M5S  Downtown Toronto
# 122        M6S      West Toronto
# 123        M7S      Not assigned
# 124        M8S      Not assigned
# 125        M9S      Not assigned
# 126        M1T       Scarborough
# 127        M2T      Not assigned
# 128        M3T      Not assigned
# 129        M4T   Central Toronto
# 130        M5T  Downtown Toronto
# 131        M6T      Not assigned
# 132        M7T      Not assigned
# 133        M8T      Not assigned
# 134        M9T      Not assigned
# 135        M1V       Scarborough
# 136        M2V      Not assigned
# 137        M3V      Not assigned
# 138        M4V   Central Toronto
# 139        M5V  Downtown Toronto
# 140        M6V      Not assigned
# 141        M7V      Not assigned
# 142        M8V         Etobicoke
# 143        M9V         Etobicoke
# 144        M1W       Scarborough
# 145        M2W      Not assigned
# 146        M3W      Not assigned
# 147        M4W  Downtown Toronto
# 148        M5W  Downtown Toronto
# 149        M6W      Not assigned
# 150        M7W      Not assigned
# 151        M8W         Etobicoke
# 152        M9W         Etobicoke
# 153        M1X       Scarborough
# 154        M2X      Not assigned
# 155        M3X      Not assigned
# 156        M4X  Downtown Toronto
# 157        M5X  Downtown Toronto
# 158        M6X      Not assigned
# 159        M7X      Not assigned
# 160        M8X         Etobicoke
# 161        M9X      Not assigned
# 162        M1Y      Not assigned
# 163        M2Y      Not assigned
# 164        M3Y      Not assigned
# 165        M4Y  Downtown Toronto
# 166        M5Y      Not assigned
# 167        M6Y      Not assigned
# 168        M7Y      East Toronto
# 169        M8Y         Etobicoke
# 170        M9Y      Not assigned
# 171        M1Z      Not assigned
# 172        M2Z      Not assigned
# 173        M3Z      Not assigned
# 174        M4Z      Not assigned
# 175        M5Z      Not assigned
# 176        M6Z      Not assigned
# 177        M7Z      Not assigned
# 178        M8Z         Etobicoke
# 179        M9Z      Not assigned
# 180        M1A      Not assigned
# 181        M2A      Not assigned
# 182        M3A        North York
# 183        M4A        North York
# 184        M5A  Downtown Toronto
# 185        M6A        North York
# 186        M7A  Downtown Toronto
# 187        M8A      Not assigned
# 188        M9A         Etobicoke
# 189        M1B       Scarborough
# 190        M2B      Not assigned
# 191        M3B        North York
# 192        M4B         East York
# 193        M5B  Downtown Toronto
# 194        M6B        North York
# 195        M7B      Not assigned
# 196        M8B      Not assigned
# 197        M9B         Etobicoke
# 198        M1C       Scarborough
# 199        M2C      Not assigned
# 200        M3C        North York
# 201        M4C         East York
# 202        M5C  Downtown Toronto
# 203        M6C              York
# 204        M7C      Not assigned
# 205        M8C      Not assigned
# 206        M9C         Etobicoke
# 207        M1E       Scarborough
# 208        M2E      Not assigned
# 209        M3E      Not assigned
# 210        M4E      East Toronto
# 211        M5E  Downtown Toronto
# 212        M6E              York
# 213        M7E      Not assigned
# 214        M8E      Not assigned
# 215        M9E      Not assigned
# 216        M1G       Scarborough
# 217        M2G      Not assigned
# 218        M3G      Not assigned
# 219        M4G         East York
# 220        M5G  Downtown Toronto
# 221        M6G  Downtown Toronto
# 222        M7G      Not assigned
# 223        M8G      Not assigned
# 224        M9G      Not assigned
# 225        M1H       Scarborough
# 226        M2H        North York
# 227        M3H        North York
# 228        M4H         East York
# 229        M5H  Downtown Toronto
# 230        M6H      West Toronto
# 231        M7H      Not assigned
# 232        M8H      Not assigned
# 233        M9H      Not assigned
# 234        M1J       Scarborough
# 235        M2J        North York
# 236        M3J        North York
# 237        M4J         East York
# 238        M5J  Downtown Toronto
# 239        M6J      West Toronto
# 240        M7J      Not assigned
# 241        M8J      Not assigned
# 242        M9J      Not assigned
# 243        M1K       Scarborough
# 244        M2K        North York
# 245        M3K        North York
# 246        M4K      East Toronto
# 247        M5K  Downtown Toronto
# 248        M6K      West Toronto
# 249        M7K      Not assigned
# 250        M8K      Not assigned
# 251        M9K      Not assigned
# 252        M1L       Scarborough
# 253        M2L        North York
# 254        M3L        North York
# 255        M4L      East Toronto
# 256        M5L  Downtown Toronto
# 257        M6L        North York
# 258        M7L      Not assigned
# 259        M8L      Not assigned
# 260        M9L        North York
# 261        M1M       Scarborough
# 262        M2M        North York
# 263        M3M        North York
# 264        M4M      East Toronto
# 265        M5M        North York
# 266        M6M              York
# 267        M7M      Not assigned
# 268        M8M      Not assigned
# 269        M9M        North York
# 270        M1N       Scarborough
# 271        M2N        North York
# 272        M3N        North York
# 273        M4N   Central Toronto
# 274        M5N   Central Toronto
# 275        M6N              York
# 276        M7N      Not assigned
# 277        M8N      Not assigned
# 278        M9N              York
# 279        M1P       Scarborough
# 280        M2P        North York
# 281        M3P      Not assigned
# 282        M4P   Central Toronto
# 283        M5P   Central Toronto
# 284        M6P      West Toronto
# 285        M7P      Not assigned
# 286        M8P      Not assigned
# 287        M9P         Etobicoke
# 288        M1R       Scarborough
# 289        M2R        North York
# 290        M3R      Not assigned
# 291        M4R   Central Toronto
# 292        M5R   Central Toronto
# 293        M6R      West Toronto
# 294        M7R       Mississauga
# 295        M8R      Not assigned
# 296        M9R         Etobicoke
# 297        M1S       Scarborough
# 298        M2S      Not assigned
# 299        M3S      Not assigned
# 300        M4S   Central Toronto
# 301        M5S  Downtown Toronto
# 302        M6S      West Toronto
# 303        M7S      Not assigned
# 304        M8S      Not assigned
# 305        M9S      Not assigned
# 306        M1T       Scarborough
# 307        M2T      Not assigned
# 308        M3T      Not assigned
# 309        M4T   Central Toronto
# 310        M5T  Downtown Toronto
# 311        M6T      Not assigned
# 312        M7T      Not assigned
# 313        M8T      Not assigned
# 314        M9T      Not assigned
# 315        M1V       Scarborough
# 316        M2V      Not assigned
# 317        M3V      Not assigned
# 318        M4V   Central Toronto
# 319        M5V  Downtown Toronto
# 320        M6V      Not assigned
# 321        M7V      Not assigned
# 322        M8V         Etobicoke
# 323        M9V         Etobicoke
# 324        M1W       Scarborough
# 325        M2W      Not assigned
# 326        M3W      Not assigned
# 327        M4W  Downtown Toronto
# 328        M5W  Downtown Toronto
# 329        M6W      Not assigned
# 330        M7W      Not assigned
# 331        M8W         Etobicoke
# 332        M9W         Etobicoke
# 333        M1X       Scarborough
# 334        M2X      Not assigned
# 335        M3X      Not assigned
# 336        M4X  Downtown Toronto
# 337        M5X  Downtown Toronto
# 338        M6X      Not assigned
# 339        M7X      Not assigned
# 340        M8X         Etobicoke
# 341        M9X      Not assigned
# 342        M1Y      Not assigned
# 343        M2Y      Not assigned
# 344        M3Y      Not assigned
# 345        M4Y  Downtown Toronto
# 346        M5Y      Not assigned
# 347        M6Y      Not assigned
# 348        M7Y      East Toronto
# 349        M8Y         Etobicoke
# 350        M9Y      Not assigned
# 351        M1Z      Not assigned
# 352        M2Z      Not assigned
# 353        M3Z      Not assigned
# 354        M4Z      Not assigned
# 355        M5Z      Not assigned
# 356        M6Z      Not assigned
# 357        M7Z      Not assigned
# 358        M8Z         Etobicoke
# 359        M9Z      Not assigned
#
#                                           Neighborhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 5                     Lawrence Manor, Lawrence Heights
# 6          Queen's Park, Ontario Provincial Government
# 7                                         Not assigned
# 8              Islington Avenue, Humber Valley Village
# 9                                       Malvern, Rouge
# 10                                        Not assigned
# 11                                           Don Mills
# 12                     Parkview Hill, Woodbine Gardens
# 13                            Garden District, Ryerson
# 14                                           Glencairn
# 15                                        Not assigned
# 16                                        Not assigned
# 17   West Deane Park, Princess Gardens, Martin Grov...
# 18              Rouge Hill, Port Union, Highland Creek
# 19                                        Not assigned
# 20                                           Don Mills
# 21                                    Woodbine Heights
# 22                                      St. James Town
# 23                                  Humewood-Cedarvale
# 24                                        Not assigned
# 25                                        Not assigned
# 26   Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 27                   Guildwood, Morningside, West Hill
# 28                                        Not assigned
# 29                                        Not assigned
# 30                                         The Beaches
# 31                                         Berczy Park
# 32                                 Caledonia-Fairbanks
# 33                                        Not assigned
# 34                                        Not assigned
# 35                                        Not assigned
# 36                                              Woburn
# 37                                        Not assigned
# 38                                        Not assigned
# 39                                             Leaside
# 40                                  Central Bay Street
# 41                                            Christie
# 42                                        Not assigned
# 43                                        Not assigned
# 44                                        Not assigned
# 45                                           Cedarbrae
# 46                                   Hillcrest Village
# 47     Bathurst Manor, Wilson Heights, Downsview North
# 48                                    Thorncliffe Park
# 49                            Richmond, Adelaide, King
# 50                        Dufferin, Dovercourt Village
# 51                                        Not assigned
# 52                                        Not assigned
# 53                                        Not assigned
# 54                                 Scarborough Village
# 55                        Fairview, Henry Farm, Oriole
# 56                     Northwood Park, York University
# 57       East Toronto, Broadview North (Old East York)
# 58   Harbourfront East, Union Station, Toronto Islands
# 59                            Little Portugal, Trinity
# 60                                        Not assigned
# 61                                        Not assigned
# 62                                        Not assigned
# 63         Kennedy Park, Ionview, East Birchmount Park
# 64                                     Bayview Village
# 65                                           Downsview
# 66                        The Danforth West, Riverdale
# 67            Toronto Dominion Centre, Design Exchange
# 68        Brockton, Parkdale Village, Exhibition Place
# 69                                        Not assigned
# 70                                        Not assigned
# 71                                        Not assigned
# 72                     Golden Mile, Clairlea, Oakridge
# 73                            York Mills, Silver Hills
# 74                                           Downsview
# 75                      India Bazaar, The Beaches West
# 76                      Commerce Court, Victoria Hotel
# 77            North Park, Maple Leaf Park, Upwood Park
# 78                                        Not assigned
# 79                                        Not assigned
# 80                                       Humber Summit
# 81     Cliffside, Cliffcrest, Scarborough Village West
# 82                             Willowdale, Newtonbrook
# 83                                           Downsview
# 84                                     Studio District
# 85                   Bedford Park, Lawrence Manor East
# 86    Del Ray, Mount Dennis, Keelsdale and Silverthorn
# 87                                        Not assigned
# 88                                        Not assigned
# 89                                    Humberlea, Emery
# 90                         Birch Cliff, Cliffside West
# 91                         Willowdale, Willowdale East
# 92                                           Downsview
# 93                                       Lawrence Park
# 94                                            Roselawn
# 95                       Runnymede, The Junction North
# 96                                        Not assigned
# 97                                        Not assigned
# 98                                              Weston
# 99   Dorset Park, Wexford Heights, Scarborough Town...
# 100                                    York Mills West
# 101                                       Not assigned
# 102                                   Davisville North
# 103    Forest Hill North & West, Forest Hill Road Park
# 104                      High Park, The Junction South
# 105                                       Not assigned
# 106                                       Not assigned
# 107                                          Westmount
# 108                                  Wexford, Maryvale
# 109                        Willowdale, Willowdale West
# 110                                       Not assigned
# 111                 North Toronto West,  Lawrence Park
# 112                The Annex, North Midtown, Yorkville
# 113                             Parkdale, Roncesvalles
# 114              Canada Post Gateway Processing Centre
# 115                                       Not assigned
# 116  Kingsview Village, St. Phillips, Martin Grove ...
# 117                                          Agincourt
# 118                                       Not assigned
# 119                                       Not assigned
# 120                                         Davisville
# 121                     University of Toronto, Harbord
# 122                                 Runnymede, Swansea
# 123                                       Not assigned
# 124                                       Not assigned
# 125                                       Not assigned
# 126            Clarks Corners, Tam O'Shanter, Sullivan
# 127                                       Not assigned
# 128                                       Not assigned
# 129                        Moore Park, Summerhill East
# 130          Kensington Market, Chinatown, Grange Park
# 131                                       Not assigned
# 132                                       Not assigned
# 133                                       Not assigned
# 134                                       Not assigned
# 135  Milliken, Agincourt North, Steeles East, L'Amo...
# 136                                       Not assigned
# 137                                       Not assigned
# 138  Summerhill West, Rathnelly, South Hill, Forest...
# 139  CN Tower, King and Spadina, Railway Lands, Har...
# 140                                       Not assigned
# 141                                       Not assigned
# 142       New Toronto, Mimico South, Humber Bay Shores
# 143  South Steeles, Silverstone, Humbergate, Jamest...
# 144                      Steeles West, L'Amoreaux West
# 145                                       Not assigned
# 146                                       Not assigned
# 147                                           Rosedale
# 148                                     Stn A PO Boxes
# 149                                       Not assigned
# 150                                       Not assigned
# 151                             Alderwood, Long Branch
# 152                Northwest, West Humber - Clairville
# 153                                        Upper Rouge
# 154                                       Not assigned
# 155                                       Not assigned
# 156                        St. James Town, Cabbagetown
# 157             First Canadian Place, Underground city
# 158                                       Not assigned
# 159                                       Not assigned
# 160      The Kingsway, Montgomery Road, Old Mill North
# 161                                       Not assigned
# 162                                       Not assigned
# 163                                       Not assigned
# 164                                       Not assigned
# 165                               Church and Wellesley
# 166                                       Not assigned
# 167                                       Not assigned
# 168  Business reply mail Processing Centre, South C...
# 169  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 170                                       Not assigned
# 171                                       Not assigned
# 172                                       Not assigned
# 173                                       Not assigned
# 174                                       Not assigned
# 175                                       Not assigned
# 176                                       Not assigned
# 177                                       Not assigned
# 178  Mimico NW, The Queensway West, South of Bloor,...
# 179                                       Not assigned
# 180                                       Not assigned
# 181                                       Not assigned
# 182                                          Parkwoods
# 183                                   Victoria Village
# 184                          Regent Park, Harbourfront
# 185                   Lawrence Manor, Lawrence Heights
# 186        Queen's Park, Ontario Provincial Government
# 187                                       Not assigned
# 188            Islington Avenue, Humber Valley Village
# 189                                     Malvern, Rouge
# 190                                       Not assigned
# 191                                          Don Mills
# 192                    Parkview Hill, Woodbine Gardens
# 193                           Garden District, Ryerson
# 194                                          Glencairn
# 195                                       Not assigned
# 196                                       Not assigned
# 197  West Deane Park, Princess Gardens, Martin Grov...
# 198             Rouge Hill, Port Union, Highland Creek
# 199                                       Not assigned
# 200                                          Don Mills
# 201                                   Woodbine Heights
# 202                                     St. James Town
# 203                                 Humewood-Cedarvale
# 204                                       Not assigned
# 205                                       Not assigned
# 206  Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 207                  Guildwood, Morningside, West Hill
# 208                                       Not assigned
# 209                                       Not assigned
# 210                                        The Beaches
# 211                                        Berczy Park
# 212                                Caledonia-Fairbanks
# 213                                       Not assigned
# 214                                       Not assigned
# 215                                       Not assigned
# 216                                             Woburn
# 217                                       Not assigned
# 218                                       Not assigned
# 219                                            Leaside
# 220                                 Central Bay Street
# 221                                           Christie
# 222                                       Not assigned
# 223                                       Not assigned
# 224                                       Not assigned
# 225                                          Cedarbrae
# 226                                  Hillcrest Village
# 227    Bathurst Manor, Wilson Heights, Downsview North
# 228                                   Thorncliffe Park
# 229                           Richmond, Adelaide, King
# 230                       Dufferin, Dovercourt Village
# 231                                       Not assigned
# 232                                       Not assigned
# 233                                       Not assigned
# 234                                Scarborough Village
# 235                       Fairview, Henry Farm, Oriole
# 236                    Northwood Park, York University
# 237      East Toronto, Broadview North (Old East York)
# 238  Harbourfront East, Union Station, Toronto Islands
# 239                           Little Portugal, Trinity
# 240                                       Not assigned
# 241                                       Not assigned
# 242                                       Not assigned
# 243        Kennedy Park, Ionview, East Birchmount Park
# 244                                    Bayview Village
# 245                                          Downsview
# 246                       The Danforth West, Riverdale
# 247           Toronto Dominion Centre, Design Exchange
# 248       Brockton, Parkdale Village, Exhibition Place
# 249                                       Not assigned
# 250                                       Not assigned
# 251                                       Not assigned
# 252                    Golden Mile, Clairlea, Oakridge
# 253                           York Mills, Silver Hills
# 254                                          Downsview
# 255                     India Bazaar, The Beaches West
# 256                     Commerce Court, Victoria Hotel
# 257           North Park, Maple Leaf Park, Upwood Park
# 258                                       Not assigned
# 259                                       Not assigned
# 260                                      Humber Summit
# 261    Cliffside, Cliffcrest, Scarborough Village West
# 262                            Willowdale, Newtonbrook
# 263                                          Downsview
# 264                                    Studio District
# 265                  Bedford Park, Lawrence Manor East
# 266   Del Ray, Mount Dennis, Keelsdale and Silverthorn
# 267                                       Not assigned
# 268                                       Not assigned
# 269                                   Humberlea, Emery
# 270                        Birch Cliff, Cliffside West
# 271                        Willowdale, Willowdale East
# 272                                          Downsview
# 273                                      Lawrence Park
# 274                                           Roselawn
# 275                      Runnymede, The Junction North
# 276                                       Not assigned
# 277                                       Not assigned
# 278                                             Weston
# 279  Dorset Park, Wexford Heights, Scarborough Town...
# 280                                    York Mills West
# 281                                       Not assigned
# 282                                   Davisville North
# 283    Forest Hill North & West, Forest Hill Road Park
# 284                      High Park, The Junction South
# 285                                       Not assigned
# 286                                       Not assigned
# 287                                          Westmount
# 288                                  Wexford, Maryvale
# 289                        Willowdale, Willowdale West
# 290                                       Not assigned
# 291                 North Toronto West,  Lawrence Park
# 292                The Annex, North Midtown, Yorkville
# 293                             Parkdale, Roncesvalles
# 294              Canada Post Gateway Processing Centre
# 295                                       Not assigned
# 296  Kingsview Village, St. Phillips, Martin Grove ...
# 297                                          Agincourt
# 298                                       Not assigned
# 299                                       Not assigned
# 300                                         Davisville
# 301                     University of Toronto, Harbord
# 302                                 Runnymede, Swansea
# 303                                       Not assigned
# 304                                       Not assigned
# 305                                       Not assigned
# 306            Clarks Corners, Tam O'Shanter, Sullivan
# 307                                       Not assigned
# 308                                       Not assigned
# 309                        Moore Park, Summerhill East
# 310          Kensington Market, Chinatown, Grange Park
# 311                                       Not assigned
# 312                                       Not assigned
# 313                                       Not assigned
# 314                                       Not assigned
# 315  Milliken, Agincourt North, Steeles East, L'Amo...
# 316                                       Not assigned
# 317                                       Not assigned
# 318  Summerhill West, Rathnelly, South Hill, Forest...
# 319  CN Tower, King and Spadina, Railway Lands, Har...
# 320                                       Not assigned
# 321                                       Not assigned
# 322       New Toronto, Mimico South, Humber Bay Shores
# 323  South Steeles, Silverstone, Humbergate, Jamest...
# 324                      Steeles West, L'Amoreaux West
# 325                                       Not assigned
# 326                                       Not assigned
# 327                                           Rosedale
# 328                                     Stn A PO Boxes
# 329                                       Not assigned
# 330                                       Not assigned
# 331                             Alderwood, Long Branch
# 332                Northwest, West Humber - Clairville
# 333                                        Upper Rouge
# 334                                       Not assigned
# 335                                       Not assigned
# 336                        St. James Town, Cabbagetown
# 337             First Canadian Place, Underground city
# 338                                       Not assigned
# 339                                       Not assigned
# 340      The Kingsway, Montgomery Road, Old Mill North
# 341                                       Not assigned
# 342                                       Not assigned
# 343                                       Not assigned
# 344                                       Not assigned
# 345                               Church and Wellesley
# 346                                       Not assigned
# 347                                       Not assigned
# 348  Business reply mail Processing Centre, South C...
# 349  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 350                                       Not assigned
# 351                                       Not assigned
# 352                                       Not assigned
# 353                                       Not assigned
# 354                                       Not assigned
# 355                                       Not assigned
# 356                                       Not assigned
# 357                                       Not assigned
# 358  Mimico NW, The Queensway West, South of Bloor,...
# 359                                       Not assigned

# %% [markdown]
# ## Combine rows into one row with the neighborhoods separated with a comma if there are more than one neighborhood for a given Postalcode and Borough

# %%
neighborhoods_grouped = neighborhoods.groupby(['PostalCode', 'Borough']).agg(','.join)
neighborhoods_grouped = neighborhoods_grouped.reset_index()

# %%
neighborhoods_grouped.head()
# Out:
#   PostalCode       Borough                            Neighborhood
# 0        M1A  Not assigned                            Not assigned
# 1        M1B   Scarborough                          Malvern, Rouge
# 2        M1C   Scarborough  Rouge Hill, Port Union, Highland Creek
# 3        M1E   Scarborough       Guildwood, Morningside, West Hill
# 4        M1G   Scarborough                                  Woburn

# %% [markdown]
# ## If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough.

# %%
neighborhoods_grouped.loc[neighborhoods_grouped['Neighborhood'] == 'Not assigned' , 'Neighborhood'] = neighborhoods_grouped['Borough']
neighborhoods_grouped.head(10)
# Out:
#   PostalCode       Borough                                     Neighborhood
# 0        M1A  Not assigned                                     Not assigned
# 1        M1B   Scarborough                                   Malvern, Rouge
# 2        M1C   Scarborough           Rouge Hill, Port Union, Highland Creek
# 3        M1E   Scarborough                Guildwood, Morningside, West Hill
# 4        M1G   Scarborough                                           Woburn
# 5        M1H   Scarborough                                        Cedarbrae
# 6        M1J   Scarborough                              Scarborough Village
# 7        M1K   Scarborough      Kennedy Park, Ionview, East Birchmount Park
# 8        M1L   Scarborough                  Golden Mile, Clairlea, Oakridge
# 9        M1M   Scarborough  Cliffside, Cliffcrest, Scarborough Village West

# %% [markdown]
# ## To print the number of rows of dataframe

# %%
neighborhoods_grouped.shape
# Out:
# (180, 3)
